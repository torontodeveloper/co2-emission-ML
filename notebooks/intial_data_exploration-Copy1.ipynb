# %%
import pandas as pd
import sys
sys.path.append('..')  # Move one level up in the directory structure
from src.data.get_dataset import get_merged_datasets, get_merged_code_books

merged_df = get_merged_datasets()
merged_df
# Out:
#             country  year iso_code  population           gdp  cement_co2  \
# 0       Afghanistan  1900      AFG   4707744.0           NaN         NaN
# 1       Afghanistan  1901      AFG   4751177.0           NaN         NaN
# 2       Afghanistan  1902      AFG   4802500.0           NaN         NaN
# 3       Afghanistan  1903      AFG   4861833.0           NaN         NaN
# 4       Afghanistan  1904      AFG   4921891.0           NaN         NaN
# ...             ...   ...      ...         ...           ...         ...
# 232538     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10       0.469
# 232539     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 232540     Zimbabwe  2019      ZWE  15354606.0           NaN       0.570
# 232541     Zimbabwe  2020      ZWE  15669663.0           NaN       0.570
# 232542     Zimbabwe  2021      ZWE  15993525.0           NaN       0.570
#
#         cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
file_path = "/Users/akshaysapra/co2-emission-ML/src/data/Time Series - GHGs from Agriculture, in kt CO₂ equivalent.xlsx"

data = pd.read_excel(file_path)

print(data.head())
# Out:
#   Time Series - GHGs from Agriculture, in kt CO₂ equivalent    Unnamed: 1  \
# 0                                                NaN                  NaN
# 1                                              Party            Base year
# 2                                          Australia         84926.981856
# 3                                            Austria          8399.709224
# 4                                            Belarus         29869.317438
#
#      Unnamed: 2    Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1          1990          1991          1992          1993          1994
# 2  84926.981856  84131.039797  81404.155876  79409.420148  79465.416064
# 3   8399.709224   8310.599653   7968.442515   8073.152598   8035.802719
# 4  29869.317438  28454.454074   25542.52278  24742.298984   21373.14641
#
#      Unnamed: 7    Unnamed: 8    Unnamed: 9  ...   Unnamed: 25   Unnamed: 26  \
# ...

# %%
pwd
# Out:
# '/Users/akshaysapra/co2-emission-ML/notebooks'
